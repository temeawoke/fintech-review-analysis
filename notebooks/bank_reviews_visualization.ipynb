# %%
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import pandas as pd
import matplotlib.pyplot as plt
# Optional: Set styles
sns.set(style="whitegrid")
# %matplotlib inline

# %%
# Load your dataset
df = pd.read_csv("data/bank_reviews_sentiment_textblob.csv")
# Check for missing values
print(df.head())
print(df.columns)
# Out:
#                                               review  rating        date  \
# 0  really am happy to this app it is Siple to use...       5  2025-06-07
# 1  I liked this app. But the User interface is ve...       2  2025-06-07
# 2  "Why don’t your ATMs support account-to-accoun...       4  2025-06-06
# 3                        what is this app problem???       1  2025-06-05
# 4       the app is proactive and a good connections.       5  2025-06-05
#
#                           bank       source sentiment
# 0  Commercial Bank of Ethiopia  Google Play  Positive
# 1  Commercial Bank of Ethiopia  Google Play  Positive
# 2  Commercial Bank of Ethiopia  Google Play  Negative
# 3  Commercial Bank of Ethiopia  Google Play   Neutral
# 4  Commercial Bank of Ethiopia  Google Play  Positive
# Index(['review', 'rating', 'date', 'bank', 'source', 'sentiment'], dtype='object')

# %%
print(df.columns.tolist())
df.columns = df.columns.str.strip()
# Out:
# ['review', 'rating', 'date', 'bank', 'source', 'sentiment']

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='bank', hue='sentiment')
plt.title('Sentiment Distribution per Bank')
plt.xlabel('Bank')
plt.ylabel('Number of Reviews')
plt.legend(title='Sentiment')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='bank', hue='sentiment')
plt.title('Average Sentiment Score per Bank')
plt.xlabel('Bank')
plt.ylabel('Average Sentiment Score')
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='bank', hue='sentiment')
plt.title("Sentiment Distribution by Bank")
plt.xlabel("Sentiment")
plt.ylabel("Number of Reviews")
plt.legend(title="Bank")
plt.show()

# %% [markdown]
# Word Cloud for Comercial BAnk Of Ethiopia

# %%
print(df.columns.tolist())
df.columns = df.columns.str.strip()
print(df.columns.tolist())
# Out:
# ['review', 'rating', 'date', 'bank', 'source', 'sentiment']
# ['review', 'rating', 'date', 'bank', 'source', 'sentiment']

# %%
text = " ".join(df[df['bank'] == bank_name]['review'])
# Generate word cloud
text = " ".join(df[df['bank'] == bank_name][review_col])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# %%
# Plot
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title(f"Word Cloud for {bank_name}")
plt.show()

# %% [markdown]
# Word Cloud for Bank of Abyssinia

# %%
print(df.columns.tolist())
df.columns = df.columns.str.strip()
print(df.columns.tolist())
# Out:
# ['review', 'rating', 'date', 'bank', 'source', 'sentiment']
# ['review', 'rating', 'date', 'bank', 'source', 'sentiment']

# %%
# Step 2: Set bank name and column with review text
bank_name = "Bank of Abyssinia"
review_col = 'review'  # Replace with actual column name if different

# %%
# Step 3: Filter reviews and generate word cloud text
text = " ".join(df[df['bank'] == bank_name][review_col].dropna().astype(str))
# Step 4: Generate and show the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# %%
# Plot
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title(f"Word Cloud for {bank_name}")
plt.show()

# %% [markdown]
# Word Cloud for Bank of Dashen

# %%
print(df.columns.tolist())
df.columns = df.columns.str.strip()
print(df.columns.tolist())
# Out:
# ['review', 'rating', 'date', 'bank', 'source', 'sentiment']
# ['review', 'rating', 'date', 'bank', 'source', 'sentiment']

# %%
# Step 2: Set bank name and the correct review column name
bank_name = "Dashen Bank"
review_col = 'review'  # Replace 'review' with actual column name if different

# %%
# Step 3: Filter reviews and generate word cloud
text = " ".join(df[df['bank'] == bank_name][review_col].dropna().astype(str))
# Step 4: Generate and display the Word Cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# %%
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title(f"Word Cloud for {bank_name}")
plt.show()
